# %%
# %matplotlib inline
# %matplotlib widget

import seaborn as sns
from query import * 
from dataframe_visualization import *
from performance_analysis import *

from visualize_widgets import visualize
import pandas as pd

# %%
df = pd.read_csv('sample_csv/heatmap.csv') # sample dataframe
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df.head()

# %% [markdown]
# <img src="sample_png/line.png" width="800" />
# <h4><center>(a) Line chart from Q-Tune</center></h4>
#
# <img src="sample_png/bar.png" width="800" />
# <h4><center>(b) Bar chart from OtterTune</center></h4>
#
#
# <img src="sample_png/heatmap.png" width="500" />
# <h4><center>(c) Heat-map chart from RESTUNE </center></h4>

# %%
import_and_update_data() # to import data from collected files
# Out:
# Loaded Data from Pickle
# MINDT :  2022-12-19 17:27:40
# 2022-12-19 17:29:22.520581
# Data Update Complete!

# %%
visualize() # it shows widgets for various visualization modes
#visualize(df) # for running 'dataframe visualization', dataframe argument is required
# Out:
# ...
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
